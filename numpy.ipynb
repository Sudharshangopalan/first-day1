# %%
import numpy as np
a=np.array([1,2,3,4,5,6])
print(np.argmax(a))
# Out:
# 5

# %%
b=np.array([2,4,5,6,7])
print(np.argmin(b))
# Out:
# 0

# %%
s=np.where(a>2)
s
# Out:
# (array([2, 3, 4, 5]),)

# %%
d=np.cumsum([1,2,3,5,6])
d
# Out:
# array([ 1,  3,  6, 11, 17])

# %%
r=np.random.randint(1,20,10)
r
# Out:
# array([13,  7, 16,  4,  7,  8,  6,  7, 17,  9,  1, 16,  2, 11,  5, 19, 16,
#         9, 15, 11])

# %%
a=np.array([1,2,3,4,5,6])
b=np.array([7,8,9,10,11,14])
print(np.corrcoef(a,b))
# Out:
# [[1.        0.9686196]
#  [0.9686196 1.       ]]

# %%
a=np.array([1,2,3,4,5,6])
print(a[:3])
# Out:
# [1 2 3]

# %%
print(a[3:])
# Out:
# [4 5 6]

# %%
print(a[1:6])
# Out:
# [2 3 4 5 6]

# %%
print(a[1:6:2])
# Out:
# [2 4 6]

# %%
print(a[::4])
print(a[-3:])
# Out:
# [1 5]
# [4 5 6]

# %%
print(a[-2:])
# Out:
# [5 6]

# %%
arr=np.array([[1,2,3,4],[3,4,5,6],[7,8,9,2]])
print(arr[0:1,1:3])
# Out:
# [[2 3]]

# %%
print(arr[:,1:2])
# Out:
# [[2]
#  [4]
#  [8]]

# %%
print(arr[:,::2])
# Out:
# [[1 3]
#  [3 5]
#  [7 9]]

# %%
import pandas as pd

# %%
c=pd.read_csv("StudentsPerformance.csv")
c
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
d={"name":["sudhan","ram","franklin"],
   
    "age":[20,19,26]}

# %%
c=pd.DataFrame(d)
c
# Out:
#        name  age
# 0    sudhan   20
# 1       ram   19
# 2  franklin   26

# %%
f=c.to_csv("friends.csv")

# %%
d=pd.read_csv("friends.csv")
d
# Out:
#    Unnamed: 0      name  age
# 0           0    sudhan   20
# 1           1       ram   19
# 2           2  franklin   26

# %%
print(d["age"],d["name"])
# Out:
# 0    20
# 1    19
# 2    26
# Name: age, dtype: int64 0      sudhan
# 1         ram
# 2    franklin
# Name: name, dtype: object

# %%
print(d.loc[0:1,["name","age"]])
# Out:
#      name  age
# 0  sudhan   20
# 1     ram   19

# %%
print(d.loc[:,"name"])
# Out:
# 0      sudhan
# 1         ram
# 2    franklin
# Name: name, dtype: object

# %%
print(d.loc[:,"age"])
# Out:
# 0    20
# 1    19
# 2    26
# Name: age, dtype: int64
